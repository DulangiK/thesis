# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12)

# %%
plt.rc('axes', labelsize=12, titlesize=12)

# %%
[66.60, 96.85, 90.75, 94.73, 92.97, 93.06, 95.74, 96.11, 94.91]

# %%
data = np.array ([[39.5349,49.4186,40.6977,45.9302,47.6744,50.5814,52.907,59.3023,51.1628], [51.1628,61.6279,54.6512,56.9767,60.4651,68.0233,59.8837,69.186,60.4651],[69.186,75,63.9535,68.0233,75,76.1628,76.1628,83.1395,73.8372],[68.6047,78.4884,66.8605,75,77.3256,77.907,79.0698,82.5581,80.814],[61.0465,80.814,64.5349,77.907,76.1628,82.5581,83.7209,81.9767,80.2326],[61.0465,80.814,67.4419,77.3256,77.3256,84.8837,85.4651,82.5581,79.0698],[61.0465,84.8837,63.3721,79.0698,81.9767,89.5349,86.6279,91.8605,79.0698]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction accuracy achieved for multiple ML models for different attributes for the original data")
plt.xlabel("Attributes")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Accuracy_variation_attributes_mutiple_ML_orig_data.png',dpi=500)
plt.show()

# %% [markdown]
# original data- precision

# %%
data = np.array ([[35.51,42.91,38.43,40.25,46.05,46.65,42.89,43.93,45.89],[37.56,64.24,58.44,56.97,59.4,67.39,63.05,72.71,62.64],[64.21,77.39,66.37,70.43,74.08,74.48,77.28,85.36,74.55],[68.87,77.86,69.54,72.7,76.31,76.75,78.5,81.02,78.55],[33.61,79.97,66.09,77.2,74.45,79.99,83.1,78.78,79.63],[33.61,80.19,71.08,77.5,75.64,82.41,84.9,79.53,78.25],[33.61,83.98,63.95,77.23,81.06,86.47,85.32,90.1,77.5]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction precision achieved for multiple ML models for different attributes for the original data")
plt.xlabel("Attributes")
plt.ylabel("Precision")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Precision_variation_orig_data.png',dpi=500)
plt.show()

# %% [markdown]
# original data recall

# %%
data = np.array ([[31.33,44.38,38.14,39.67,46.96,50.19,46.28,54.75,44.82],[42.27,60.56,55.3,54.45,59.06,63.11,59.18,63.71,57.47],[67.97,75.69,64.98,70.11,76.21,74.26,77.38,81.42,74.53],[69.81,77.86,67.6,73.42,75.29,76.94,78.94,80.19,78.9],[42.84,81.14,67.47,77.12,78.01,81.75,83.5,79.7,80.14],[42.84,81.14,70.16,78.6,78.28,85.02,85.77,81.36,79.38],[42.84,85.35,60.34,76.41,82.98,88.32,85.8,88.63,77.08]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction recall achieved for multiple ML models for different attributes for the original data")
plt.xlabel("Attributes")
plt.ylabel("Recall")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Recall_variation_orig_data.png',dpi=500)
plt.show()

# %% [markdown]
# kmeans smote

# %%
[41.86,87.2,100,71.51,58.14,35.47,100,40.7,56.98],[55.23,100,100,89.53,72.09,65.12,100,70.35,76.16],[73.26,100,100,93.6,80.23,78.49,100,81.98,89.53],[73.26,100,100,97.67,83.72,79.07,100,78.49,91.86],[63.37,100,100,100,88.37,84.3,100,83.72,95.93],[63.37,100,100,100,86.63,84.88,100,84.3,96.51],[63.37,100,100,100,90.7,87.21,100,91.86,98.26]

# %%
data = np.array ([[41.86,87.2,100,71.51,58.14,35.47,100,40.7,56.98],[55.23,100,100,89.53,72.09,65.12,100,70.35,76.16],[73.26,100,100,93.6,80.23,78.49,100,81.98,89.53],[73.26,100,100,97.67,83.72,79.07,100,78.49,91.86],[63.37,100,100,100,88.37,84.3,100,83.72,95.93],[63.37,100,100,100,86.63,84.88,100,84.3,96.51],[63.37,100,100,100,90.7,87.21,100,91.86,98.26]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction accuracy achieved for multiple ML models for different attributes with kmeans SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Accuracy_variation_kmeans_smote.png',dpi=500)
plt.show()

# %% [markdown]
# kmeans precision

# %%
data = np.array ([[39.99,87.1,100,68.9,55,38.2,100,37.7,53.7],[51.34,100,100,88.1,69.6,59.8,100,67.8,74.8],[71.05,100,100,92.2,77.8,75.4,100,78.8,87.3],[71.05,100,100,97.8,81.6,76.5,100,76.1,90.1],[51.72,100,100,100,87.1,82.2,100,80,95],[51.72,100,100,100,85.4,82,100,80.9,96.3],[51.72,100,100,100,89.4,84.1,100,89.3,97.9]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction precision achieved for multiple ML models for different attributes with kmeans SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Precision")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Precision_variation_kmeans_smote.png',dpi=500)
plt.show()

# %% [markdown]
# kmeans recall

# %%
[43.05,87.9,100,69.6,56.6,40.2,100,42.7,56.4],[51.49,100,100,88.6,72.9,61.9,100,68.5,75],[77.27,100,100,93.4,82.3,77.4,100,82.3,89.5],[77.27,100,100,97.3,85.6,78.5,100,78.3,92.9],[59.27,100,100,100,88.7,84.1,100,84,97.1],[59.27,100,100,100,87.9,85.7,100,84.4,97.9],[,59.27,100,100,100,92.2,88.2,100,91.4,99]

# %%
data = np.array ([[43.05,87.9,100,69.6,56.6,40.2,100,42.7,56.4],[51.49,100,100,88.6,72.9,61.9,100,68.5,75],[77.27,100,100,93.4,82.3,77.4,100,82.3,89.5],[77.27,100,100,97.3,85.6,78.5,100,78.3,92.9],[59.27,100,100,100,88.7,84.1,100,84,97.1],[59.27,100,100,100,87.9,85.7,100,84.4,97.9],[59.27,100,100,100,92.2,88.2,100,91.4,99]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction recall achieved for multiple ML models for different attributes with kmeans SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Recall")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Recall_variation_kmeans_smote.png',dpi=500)
plt.show()

# %% [markdown]
# SMOTE

# %%
data = np.array ([[47.7,44.2,44.8,44.8,44.8,50.6,49.4,58.1,50.6],[55.8,63.4,53.5,62.8,55.2,66.9,64.5,60.5,66.9],[71.5,77.3,68,77.3,73.8,78.5,77.3,76.2,78.5],[71.5,79.7,73.8,78.5,75.6,78.5,79.1,77.9,78.5],[78.5,81.4,71.5,80.2,77.9,83.1,84.9,83.1,83.1],[78.5,82,68,82,77.3,84.9,84.3,82.6,84.9],[62.2,83.7,68.6,82,79.1,82,87.2,89,82]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction accuracy achieved for multiple ML models for different attributes with SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Accuracy_variation_attributes_mutiple_ML_smote.png',dpi=500)
plt.show()

# %% [markdown]
# smote recall

# %%
data = np.array ([[45.4,38.1,39.9,40.4,40.1,44.3,41.9,49.8,44.3],[60.4,59.2,50.2,57.6,50.2,62.7,57.6,56,62.7],[71,75.3,68.6,75.3,73.5,76.8,74.5,74.3,76.8],[71,76.9,73.7,77.6,73.3,77.6,78,75.6,77.6],[78.8,80.5,71,79.8,78.7,82,81.6,81.9,82],[78.8,80.4,69.3,80.9,78,84,81.8,80.7,84],[55.6,82.5,69.5,79.9,79,81.4,86,88.6,81.4]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction recall achieved for multiple ML models for different attributes with SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Recall")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Recall_variation_attributes_mutiple_ML_smote.png',dpi=500,bbox_inches='tight')
plt.show()

# %% [markdown]
# smote precision

# %%
data = np.array ([[46.6,38.4,40.2,42.2,41.6,44.5,42.4,50.4,44.5],[57.7,62.8,50.4,61.6,51.9,66.4,59.9,57.9,66.4],[71.1,77.8,70,76,74.1,79.8,77.7,73.9,79.8],[71.1,78.6,72.9,78.5,72.1,78.5,79.1,74.6,78.5],[77.4,79.3,70.7,78.3,77.1,81.9,82.4,80.5,81.9],[77.4,80.6,67.7,80.6,75.1,84.2,82.2,78.9,84.2],[48.9,83.8,68.7,82.2,77.6,81.3,85.6,86.7,81.3]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction precision achieved for multiple ML models for different attributes with SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Precision")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
plt.savefig('Precision_variation_attributes_mutiple_ML_smote.png',dpi=500,bbox_inches='tight')
plt.show()

# %% [markdown]
# SMOTE NC

# %% [markdown]
# accuracy

# %%
data = np.array ([[45.9,45.3,43,45.3,43,41.9,44.1,58.7,47.1],[57.6,61.6,50,63.4,54.7,60.5,63.4,60.5,64.5],[70.9,77.9,77.9,77.9,72.7,77.3,76.2,77.3,79.1],[73.8,80.8,72.1,80.2,73.8,79.1,79.7,77.9,80.8],[73.3,80.2,74.4,80.8,78.5,85.5,82.6,83.7,82.6],[73.3,82.6,70.9,84.3,78.5,86,82.6,84.3,83.1],[70.3,82.6,75,79.1,83.1,88.4,86,90.1,82]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction accuracy achieved for multiple ML models for different attributes with SMOTE NC")
plt.xlabel("Attributes")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Accuracy_variation_SMOTE_NC.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# SMOTE NC ; precision

# %%
data = np.array ([[45,41.8,41.2,42.5,40.2,47.1,40.5,49.1,42.7],[66.1,61.4,51.4,63,55.9,56.1,61.8,58,68.5],[72.1,77.9,78.6,78.5,73.3,75.8,76.5,76,79.3],[69.9,81,74.5,79.7,73,76.6,80.1,75,81.4],[70.2,78.5,75.2,78.8,76.8,83.8,79.4,80.8,81.8],[70.2,81.2,69.2,83,76.3,83,79.5,81.2,82.5],[54,80.8,75.4,81.8,81.5,85.6,85.3,87.6,81.9]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction precision achieved for multiple ML models for different attributes with SMOTE NC")
plt.xlabel("Attributes")
plt.ylabel("Precision")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Precision_variation_SMOTE_NC.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# smotenc;recall

# %%
data = np.array ([[42.9,38.8,39.1,40.8,40.3,41.9,38.9,51.7,42.1],[55.8,56.6,45.5,58.4,51.7,54.3,58.3,56.1,59.9],[70.4,75.6,74.7,75,72.3,76.8,74.6,75.9,76.3],[71.8,78.8,71.4,77.9,72.4,76.7,78.1,75.3,78.8],[71.6,79.3,74.6,78.8,80.2,84.5,79.8,81.4,80.7],[71.6,81.7,70.9,84.1,80.9,85.4,80.2,83.5,82.4],[63,78.1,73.3,76.6,84.9,88.1,83.8,90,79.1]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction recall achieved for multiple ML models for different attributes with SMOTE NC")
plt.xlabel("Attributes")
plt.ylabel("Recall")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Recall_variation_SMOTE_NC.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# #SMOTE SVM

# %% [markdown]
# accuracy

# %%
data = np.array ([[41.3,45.9,38.4,46.5,45.9,49.4,44.2,53.1,52.3],[69.8,64,53.5,66.9,58.7,65.7,66.3,66,67.4],[50,79.7,73.3,77.9,74.4,78.5,79.1,78.5,76.7],[53.5,80.8,80,79.7,75,79.1,80.2,79.1,79.1],[53.5,82,76.2,80.2,79.1,84.3,83.1,83.7,82],[53.5,81.4,76.2,81.4,78.5,84.3,82.6,84.3,84.3],[53.5,83.7,73.3,80.8,82,88.4,91.9,89.5,82]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction accuracy achieved for multiple ML models for different attributes with SVM SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Accuracy_variation_SVM_SMOTE.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# precision

# %%
data = np.array ([[45.7,40.2,34.7,42.5,41.7,48,37.8,44.1,49.5],[71.6,65.5,52,70.8,57,62.7,69.9,67.2,73.8],[37.5,81.2,75.9,79.9,75.9,78.3,80.4,78.5,77.9],[46.9,82.3,77.1,80.6,74.1,79.3,81.2,77.8,79.2],[46.9,81.1,75.2,79.5,75.9,82.8,81.5,80.9,81.6],[46.9,79.9,76.2,81.6,75.8,82.1,85.2,80.4,83.5],[46.9,82.2,74.5,81,79.4,85.5,86.2,87,81.9]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction precision achieved for multiple ML models for different attributes with SVM SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Precision")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Precision_variation_SVM_SMOTE.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# recall

# %%
data = np.array ([[39.4,38.1,36.1,42.1,41.5,47.4,37.1,51,44.6],[71,56.4,46.6,62.2,53.3,58.2,59,59.6,63.3],[41.5,77.1,70.6,77.7,73.8,77.8,76.9,76.4,74.4],[53.5,79.8,76.7,77.6,73.1,77.5,77.7,76.8,76.4],[53.5,80.4,75.4,78.6,77.7,82.6,80.1,81.2,81.3],[53.5,80.1,76.2,81.9,78.5,84.2,83.9,82.6,83.6],[53.5,81,76.2,79.7,81.4,87.6,86.5,87.4,80.3]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction recall achieved for multiple ML models for different attributes with SVM SMOTE")
plt.xlabel("Attributes")
plt.ylabel("Recall")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Recall_variation_SVM_SMOTE.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# SMOTE tomek

# %% [markdown]
# accuracy

# %%
data = np.array ([[37.8,44.2,43.6,47.1,44.2,42.4,44.2,45.9,45.9], [56.4,59.9,59.3,54.7,55.8,56.4,57.6,55.8,59.9],[52.9,72.7,75,72.7,70.3,70.3,75.6,70.9,73.8],[52.9,76.7,72.7,75,75.6,75,77.3,74.4,75],[51.2,76.7,75,75.6,79.7,79.7,79.1,79.7,77.9],[51.2,79.7,73.8,77.9,79.1,80.8,81.4,79.1,78.5],[51.2,82,73.3,76.7,83.7,83.7,79.7,84.9,78.5]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction accuracy achieved for multiple ML models for different attributes with SMOTE tomek")
plt.xlabel("Attributes")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Accuracy_variation_SMOTE_tomek.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# smote tomek precision

# %%
data = np.array ([[32.6,38.8,41.4,42.9,38.9,44.1,39.1,39.1,42.3],[59.7,56.7,57.1,53.2,55.5,57.6,58.2,58.8,57.9],[45.3,71.2,70.3,68.4,69.5,69.8,72.7,70.4,71.6],[45.3,74.7,70.5,70.4,73.8,73.6,75.6,72.9,73],[46.5,75.7,71.6,74.3,77.3,76.8,77.1,76.6,74.7],[46.5,78.8,72.7,74.9,77.2,78.1,78.5,75.5,75.4],[46.5,82.2,72.2,73.9,81.8,81.6,80,82.1,75.8]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction precision achieved for multiple ML models for different attributes with SMOTE tomek")
plt.xlabel("Attributes")
plt.ylabel("Precision")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Precision_variation_SMOTE_tomek.png',dpi=500,bbox_inches='tight')
plt.show()

# %% [markdown]
# smote tomek recall

# %%
data = np.array ([[37.3,40.2,41.3,43.5,38.3,48.8,47.6,47.6,43.5],[50.1,56.9,56.6,54.2,52.4,54.4,55.9,54.8,58.8],[56.1,71.9,72.7,70.2,71.4,70.7,72.6,71.8,72.7],[56.1,75.6,70.8,72.4,73.8,74.1,75.8,73.4,73.7],[50.6,76.1,72.5,75.7,79.5,79,77.8,79.3,77],[50.6,79.9,75,76.1,80.4,81.1,79.5,78.5,77.8],[50.6,80.6,73.5,74.5,84.3,84.2,80.2,84.8,76]])
x = np.array(["S1+pre+Dim","S1+S2+pre+Dim","S1+S2+S3+pre+Dim","S1+S2+S3+S4+pre+Dim","S1+S2+S3+S4+S5+pre+Dim","S1+S2+S3+S4+S5+S6+pre+Dim","S1+S2+S3+S4+S5+S6+S7+pre+Dim"])

# %%
plt.figure(figsize=(10,6))

plt.xticks(rotation=20)
plt.rcParams["figure.autolayout"] = True
plt.plot(x, data[:,0], marker = 'o', label='AdaBoost')
plt.plot(x, data[:,1], marker = 'o', label='CatBoost')
plt.plot(x, data[:,2], marker = 'o', label='Decision Tree')
#plt.plot(x, data[:,2], marker = 'o', label='Ensemble')
plt.plot(x, data[:,3], marker = 'o', label='Gradient Boosting')
plt.plot(x, data[:,4], marker = 'o', label='KNN')
plt.plot(x, data[:,5], marker = 'o', label='Naive Bayes')
plt.plot(x, data[:,6], marker = 'o', label='Random Forest')
plt.plot(x, data[:,7], marker = 'o', label='SVM')
plt.plot(x, data[:,8], marker = 'o', label='XgBoost')
plt.title("Prediction recall achieved for multiple ML models for different attributes with SMOTE tomek")
plt.xlabel("Attributes")
plt.ylabel("Recall")
plt.legend(loc='lower right')
plt.subplots_adjust(bottom=0.1)
#plt.savefig('Accuracy_variation_all_attributes_multiple_ML_with_SMOTETomec.png',dpi=500)
plt.savefig('Recall_variation_SMOTE_tomek.png',dpi=500,bbox_inches='tight')
plt.show()
